# %%
import pandas as pd
df = pd.read_csv("Outliers_z-score.csv")
df
# Out:
#      Unnamed: 0      height        age      weight         income  \
# 0             0  174.967142  27.923146   75.366810   37565.074836
# 1             1  168.617357  32.896773   78.411768   41597.284397
# 2             2  176.476885  33.286427   86.245769   61209.404077
# 3             3  185.230299  30.988614   85.807031   59155.553982
# 4             4  167.658466  34.193571   49.334959   49686.476091
# ..          ...         ...        ...         ...            ...
# 97           97  172.610553  35.768626   74.609493   70308.085612
# 98           98  170.051135  35.291044   82.192932   48281.902321
# 99           99  167.654129  29.285149   79.444433   68567.244680
# 100         100  250.000000  80.000000  150.000000  150000.000000
# 101         101  120.000000  10.000000   30.000000   20000.000000
#
#      hours_per_week  years_experience  satisfaction  performance  \
# 0         32.027862         12.778533      8.513977    69.772770
# ...

# %%
df.drop(columns= "Unnamed: 0",inplace= True)

# %% [markdown]
# ### Calculate the Z-scores for the 'height' column and identify outliers.

# %%
upper_limit = df["height"].mean() + 3 * df["height"].std()
lower_limit = df["height"].mean() - 3 * df["height"].std()
upper_limit , lower_limit
# Out:
# (208.3337773191619, 130.2182517515421)

# %%
df[(df["height"]>=upper_limit)|(df["height"]<=lower_limit)]
# Out:
#      Unnamed: 0  height   age  weight    income  hours_per_week  \
# 100         100   250.0  80.0   150.0  150000.0            80.0
# 101         101   120.0  10.0    30.0   20000.0            10.0
#
#      years_experience  satisfaction  performance  projects_completed    bonus
# 100              30.0          10.0        100.0                15.0  20000.0
# 101               1.0           0.0         50.0                 0.0      0.0

# %% [markdown]
# ### Remove the outliers from the 'height' column based on Z-scores and display the cleaned column.

# %%
df_height = df[(df["height"]<=upper_limit )&(df["height"]>=lower_limit)]
df_height
# Out:
#     Unnamed: 0      height        age     weight        income  \
# 0            0  174.967142  27.923146  75.366810  37565.074836
# 1            1  168.617357  32.896773  78.411768  41597.284397
# 2            2  176.476885  33.286427  86.245769  61209.404077
# 3            3  185.230299  30.988614  85.807031  59155.553982
# 4            4  167.658466  34.193571  49.334959  49686.476091
# ..         ...         ...        ...        ...           ...
# 95          95  155.364851  36.926587  59.606356  42962.365218
# 96          96  172.961203  30.580713  83.493998  24302.982064
# 97          97  172.610553  35.768626  74.609493  70308.085612
# 98          98  170.051135  35.291044  82.192932  48281.902321
# 99          99  167.654129  29.285149  79.444433  68567.244680
#
#     hours_per_week  years_experience  satisfaction  performance  \
# 0        32.027862         12.778533      8.513977    69.772770
# 1        37.003125         15.728250      5.155669    85.490092
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
# before removal outliers

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.distplot(df["height"])
plt.title("before removal outliers")

# after removal ourliers
plt.subplot(1,2,2)
sns.distplot(df_height["height"])
plt.title("after removal outliers")
            
plt.show()

# %% [markdown]
# ### Calculate the Z-scores for the 'age' column and identify outliers.

# %%
upper_limit = df["age"].mean() + 3 * df["age"].std()
lower_limit = df["age"].mean() - 3 * df["age"].std()
upper_limit , lower_limit
# Out:
# (56.18563207927538, 14.425197205527795)

# %%
df[(df["age"]>=upper_limit)|(df["age"]<=lower_limit)]
# Out:
#      height   age  weight    income  hours_per_week  years_experience  \
# 100   250.0  80.0   150.0  150000.0            80.0              30.0
# 101   120.0  10.0    30.0   20000.0            10.0               1.0
#
#      satisfaction  performance  projects_completed    bonus
# 100          10.0        100.0                15.0  20000.0
# 101           0.0         50.0                 0.0      0.0

# %% [markdown]
# ### Remove the outliers from the 'age' column based on Z-scores and display the cleaned column.

# %%
df_age = df[(df["age"]<=upper_limit)&(df["age"]>=lower_limit)]
df_age
# Out:
#         height        age     weight        income  hours_per_week  \
# 0   174.967142  27.923146  75.366810  37565.074836       32.027862
# 1   168.617357  32.896773  78.411768  41597.284397       37.003125
# 2   176.476885  33.286427  86.245769  61209.404077       40.026218
# 3   185.230299  30.988614  85.807031  59155.553982       40.234903
# 4   167.658466  34.193571  49.334959  49686.476091       37.749673
# ..         ...        ...        ...           ...             ...
# 95  155.364851  36.926587  59.606356  42962.365218       42.694550
# 96  172.961203  30.580713  83.493998  24302.982064       34.813769
# 97  172.610553  35.768626  74.609493  70308.085612       39.048307
# 98  170.051135  35.291044  82.192932  48281.902321       35.621909
# 99  167.654129  29.285149  79.444433  68567.244680       33.086001
#
#     years_experience  satisfaction  performance  projects_completed  \
# 0          12.778533      8.513977    69.772770            6.876568
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.distplot(df["age"])
plt.title("before removal outliers")

# after removal ourliers
plt.subplot(1,2,2)
sns.distplot(df_age["age"])
plt.title("after removal outliers")
            
plt.show()

# %% [markdown]
# ### Calculate the Z-scores for the 'weight' column and identify outliers.

# %%
upper_limit = df["weight"].mean() + 3 * df["weight"].std()
lower_limit = df["weight"].mean() - 3 * df["weight"].std()
upper_limit , lower_limit
# Out:
# (126.46840597257743, 16.2246210793965)

# %%
df[(df["weight"]>= upper_limit)|(df["weight"]<=lower_limit)]
# Out:
#        height       age      weight         income  hours_per_week  \
# 9    175.4256  34.62777  127.790972   46967.110213       42.572194
# 100  250.0000  80.00000  150.000000  150000.000000       80.000000
#
#      years_experience  satisfaction  performance  projects_completed  \
# 9             7.50715      9.992089    91.964564            3.210785
# 100          30.00000     10.000000   100.000000           15.000000
#
#             bonus
# 9     8326.509447
# 100  20000.000000

# %% [markdown]
# ### Remove the outliers from the 'weight' column based on Z-scores and display the cleaned column.

# %%
df_weight = df[(df["weight"]<= upper_limit)&(df["weight"]>=lower_limit)]
df_weight
# Out:
#          height        age     weight        income  hours_per_week  \
# 0    174.967142  27.923146  75.366810  37565.074836       32.027862
# 1    168.617357  32.896773  78.411768  41597.284397       37.003125
# 2    176.476885  33.286427  86.245769  61209.404077       40.026218
# 3    185.230299  30.988614  85.807031  59155.553982       40.234903
# 4    167.658466  34.193571  49.334959  49686.476091       37.749673
# ..          ...        ...        ...           ...             ...
# 96   172.961203  30.580713  83.493998  24302.982064       34.813769
# 97   172.610553  35.768626  74.609493  70308.085612       39.048307
# 98   170.051135  35.291044  82.192932  48281.902321       35.621909
# 99   167.654129  29.285149  79.444433  68567.244680       33.086001
# 101  120.000000  10.000000  30.000000  20000.000000       10.000000
#
#      years_experience  satisfaction  performance  projects_completed  \
# 0           12.778533      8.513977    69.772770            6.876568
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.distplot(df["weight"])
plt.title("before removal outliers")

# after removal ourliers
plt.subplot(1,2,2)
sns.distplot(df_weight["weight"])
plt.title("after removal outliers")
            
plt.show()

# %% [markdown]
# ### Calculate the Z-scores for the 'income' column and identify outliers.

# %%
upper_limit = df["income"].mean() + 3 * df["income"].std()
lower_limit = df["income"].mean() - 3 * df["income"].std()
upper_limit , lower_limit
# Out:
# (102250.68256025728, 2264.2229504477727)

# %%
df[(df["income"]>= upper_limit)|(df["income"]<=lower_limit)]
# Out:
#      height   age  weight    income  hours_per_week  years_experience  \
# 100   250.0  80.0   150.0  150000.0            80.0              30.0
#
#      satisfaction  performance  projects_completed    bonus
# 100          10.0        100.0                15.0  20000.0

# %% [markdown]
# ### Remove the outliers from the 'income' column based on Z-scores and display the cleaned column.

# %%
df_income = df[(df["income"]<= upper_limit)&(df["income"]>=lower_limit)]
df_income
# Out:
#          height        age     weight        income  hours_per_week  \
# 0    174.967142  27.923146  75.366810  37565.074836       32.027862
# 1    168.617357  32.896773  78.411768  41597.284397       37.003125
# 2    176.476885  33.286427  86.245769  61209.404077       40.026218
# 3    185.230299  30.988614  85.807031  59155.553982       40.234903
# 4    167.658466  34.193571  49.334959  49686.476091       37.749673
# ..          ...        ...        ...           ...             ...
# 96   172.961203  30.580713  83.493998  24302.982064       34.813769
# 97   172.610553  35.768626  74.609493  70308.085612       39.048307
# 98   170.051135  35.291044  82.192932  48281.902321       35.621909
# 99   167.654129  29.285149  79.444433  68567.244680       33.086001
# 101  120.000000  10.000000  30.000000  20000.000000       10.000000
#
#      years_experience  satisfaction  performance  projects_completed  \
# 0           12.778533      8.513977    69.772770            6.876568
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.boxplot(df["income"])
plt.title("before removal outliers")

# after removal ourliers
plt.subplot(1,2,2)
sns.boxplot(df_income["income"])
plt.title("after removal outliers")
            
plt.show()

# %% [markdown]
# ### Calculate the Z-scores for the 'hours_per_week' column and identify outliers.

# %%
upper_limit = df["hours_per_week"].mean() + 3 * df["hours_per_week"].std()
lower_limit = df["hours_per_week"].mean() - 3 * df["hours_per_week"].std()
upper_limit , lower_limit
# Out:
# (61.56606805165089, 18.080946943345722)

# %%
df[(df["hours_per_week"]>=upper_limit)|(df["hours_per_week"]<= lower_limit)]
# Out:
#      height   age  weight    income  hours_per_week  years_experience  \
# 100   250.0  80.0   150.0  150000.0            80.0              30.0
# 101   120.0  10.0    30.0   20000.0            10.0               1.0
#
#      satisfaction  performance  projects_completed    bonus
# 100          10.0        100.0                15.0  20000.0
# 101           0.0         50.0                 0.0      0.0

# %% [markdown]
# ### Remove the outliers from the 'hours_per_week' column based on Z-scores and display the cleaned column.

# %%
df_hpr = df[(df["hours_per_week"]<=upper_limit)&(df["hours_per_week"]>= lower_limit)]
df_hpr
# Out:
#         height        age     weight        income  hours_per_week  \
# 0   174.967142  27.923146  75.366810  37565.074836       32.027862
# 1   168.617357  32.896773  78.411768  41597.284397       37.003125
# 2   176.476885  33.286427  86.245769  61209.404077       40.026218
# 3   185.230299  30.988614  85.807031  59155.553982       40.234903
# 4   167.658466  34.193571  49.334959  49686.476091       37.749673
# ..         ...        ...        ...           ...             ...
# 95  155.364851  36.926587  59.606356  42962.365218       42.694550
# 96  172.961203  30.580713  83.493998  24302.982064       34.813769
# 97  172.610553  35.768626  74.609493  70308.085612       39.048307
# 98  170.051135  35.291044  82.192932  48281.902321       35.621909
# 99  167.654129  29.285149  79.444433  68567.244680       33.086001
#
#     years_experience  satisfaction  performance  projects_completed  \
# 0          12.778533      8.513977    69.772770            6.876568
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.distplot(df["hours_per_week"])
plt.title("before removal outliers")

# after removal ourliers
plt.subplot(1,2,2)
sns.distplot(df_hpr["hours_per_week"])
plt.title("after removal outliers")
            
plt.show()

# %% [markdown]
# ### Calculate the Z-scores for the 'years_experience' column and identify outliers.

# %%
upper_limit = df["years_experience"].mean() + 3 * df["years_experience"].std()
lower_limit = df["years_experience"].mean() - 3 * df["years_experience"].std()
upper_limit , lower_limit
# Out:
# (20.311954358681092, -0.7745363092471109)

# %%
df[(df["years_experience"]>= upper_limit)|(df["years_experience"]<=lower_limit)]
# Out:
#      height   age  weight    income  hours_per_week  years_experience  \
# 100   250.0  80.0   150.0  150000.0            80.0              30.0
#
#      satisfaction  performance  projects_completed    bonus
# 100          10.0        100.0                15.0  20000.0

# %% [markdown]
# ### Remove the outliers from the 'years_experience' column based on Z-scores and display the cleaned column.

# %%
df_ye = df[(df["years_experience"]<= upper_limit)&(df["years_experience"]>=lower_limit)]
df_ye
# Out:
#          height        age     weight        income  hours_per_week  \
# 0    174.967142  27.923146  75.366810  37565.074836       32.027862
# 1    168.617357  32.896773  78.411768  41597.284397       37.003125
# 2    176.476885  33.286427  86.245769  61209.404077       40.026218
# 3    185.230299  30.988614  85.807031  59155.553982       40.234903
# 4    167.658466  34.193571  49.334959  49686.476091       37.749673
# ..          ...        ...        ...           ...             ...
# 96   172.961203  30.580713  83.493998  24302.982064       34.813769
# 97   172.610553  35.768626  74.609493  70308.085612       39.048307
# 98   170.051135  35.291044  82.192932  48281.902321       35.621909
# 99   167.654129  29.285149  79.444433  68567.244680       33.086001
# 101  120.000000  10.000000  30.000000  20000.000000       10.000000
#
#      years_experience  satisfaction  performance  projects_completed  \
# 0           12.778533      8.513977    69.772770            6.876568
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.distplot(df["years_experience"])
plt.title("before removal outliers")

# after removal ourliers
plt.subplot(1,2,2)
sns.distplot(df_ye["years_experience"])
plt.title("after removal outliers")
            
plt.show()

# %% [markdown]
# ### Calculate the Z-scores for the 'satisfaction' column and identify outliers.

# %%
upper_limit = df["satisfaction"].mean() + 3 * df["satisfaction"].std()
lower_limit = df["satisfaction"].mean() - 3 * df["satisfaction"].std()
upper_limit , lower_limit
# Out:
# (13.744440812343601, 0.27161355379184116)

# %%
df[(df["satisfaction"]>=upper_limit)|(df["satisfaction"]<=lower_limit)]
# Out:
#      height   age  weight   income  hours_per_week  years_experience  \
# 101   120.0  10.0    30.0  20000.0            10.0               1.0
#
#      satisfaction  performance  projects_completed  bonus
# 101           0.0         50.0                 0.0    0.0

# %% [markdown]
# ### Remove the outliers from the 'satisfaction' column based on Z-scores and display the cleaned column.

# %%
df_sat = df[(df["satisfaction"]<=upper_limit)&(df["satisfaction"]>=lower_limit)]
df_sat
# Out:
#          height        age      weight         income  hours_per_week  \
# 0    174.967142  27.923146   75.366810   37565.074836       32.027862
# 1    168.617357  32.896773   78.411768   41597.284397       37.003125
# 2    176.476885  33.286427   86.245769   61209.404077       40.026218
# 3    185.230299  30.988614   85.807031   59155.553982       40.234903
# 4    167.658466  34.193571   49.334959   49686.476091       37.749673
# ..          ...        ...         ...            ...             ...
# 96   172.961203  30.580713   83.493998   24302.982064       34.813769
# 97   172.610553  35.768626   74.609493   70308.085612       39.048307
# 98   170.051135  35.291044   82.192932   48281.902321       35.621909
# 99   167.654129  29.285149   79.444433   68567.244680       33.086001
# 100  250.000000  80.000000  150.000000  150000.000000       80.000000
#
#      years_experience  satisfaction  performance  projects_completed  \
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.distplot(df["satisfaction"])
plt.title("before removal outliers")

# after removal ourliers
plt.subplot(1,2,2)
sns.distplot(df_sat["satisfaction"])
plt.title("after removal outliers")
            
plt.show()

# %% [markdown]
# ### Calculate the Z-scores for the 'performance' column and identify outliers.

# %%
upper_limit = df["performance"].mean() + 3 * df["performance"].std()
lower_limit = df["performance"].mean() - 3 * df["performance"].std()
upper_limit , lower_limit
# Out:
# (105.75478823672613, 44.12441624352225)

# %%
df[(df["performance"]>= upper_limit)|(df["performance"]<= lower_limit)]
# Out:
# Empty DataFrame
# Columns: [height, age, weight, income, hours_per_week, years_experience, satisfaction, performance, projects_completed, bonus]
# Index: []

# %%
Q1 = df["performance"].quantile(0.25)
Q3 = df["performance"].quantile(0.75)
iqr = Q3 - Q1
iqr
# Out:
# 13.385442919847549

# %%
upper_limit = Q3 + 1.5 * iqr
lower_limit = Q1 - 1.5 * iqr
upper_limit , lower_limit
# Out:
# (101.25966947461097, 47.71789779522078)

# %%
df[(df["performance"]>= upper_limit)|(df["performance"]<= lower_limit)]
# Out:
#         height        age     weight       income  hours_per_week  \
# 55  179.312801  31.428243  62.736489  34962.05953       36.035636
#
#     years_experience  satisfaction  performance  projects_completed  \
# 55          8.764369      7.118437   101.323821            3.858507
#
#           bonus
# 55  6234.591663

# %% [markdown]
# ### Remove the outliers from the 'performance' column based on IQR and display the cleaned column.

# %%
df_per = df[(df["performance"]<= upper_limit)&(df["performance"]>= lower_limit)]
df_per
# Out:
#          height        age      weight         income  hours_per_week  \
# 0    174.967142  27.923146   75.366810   37565.074836       32.027862
# 1    168.617357  32.896773   78.411768   41597.284397       37.003125
# 2    176.476885  33.286427   86.245769   61209.404077       40.026218
# 3    185.230299  30.988614   85.807031   59155.553982       40.234903
# 4    167.658466  34.193571   49.334959   49686.476091       37.749673
# ..          ...        ...         ...            ...             ...
# 97   172.610553  35.768626   74.609493   70308.085612       39.048307
# 98   170.051135  35.291044   82.192932   48281.902321       35.621909
# 99   167.654129  29.285149   79.444433   68567.244680       33.086001
# 100  250.000000  80.000000  150.000000  150000.000000       80.000000
# 101  120.000000  10.000000   30.000000   20000.000000       10.000000
#
#      years_experience  satisfaction  performance  projects_completed  \
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.boxplot(df["performance"])
plt.title("before removal outliers")

# after removal ourliers
plt.subplot(1,2,2)
sns.boxplot(df_per["performance"])
plt.title("after removal outliers")
            
plt.show()

# %% [markdown]
# ### Calculate the Z-scores for the 'projects_completed' column and identify outliers.

# %%
upper_limit = df["projects_completed"].mean() + 3 * df["projects_completed"].std()
lower_limit = df["projects_completed"].mean() - 3 * df["projects_completed"].std()
upper_limit , lower_limit
# Out:
# (11.957950322014844, -0.9632480992744075)

# %%
df[(df["projects_completed"]>= upper_limit)|(df["projects_completed"]<=lower_limit)]
# Out:
#      height   age  weight    income  hours_per_week  years_experience  \
# 100   250.0  80.0   150.0  150000.0            80.0              30.0
#
#      satisfaction  performance  projects_completed    bonus
# 100          10.0        100.0                15.0  20000.0

# %% [markdown]
# ### Remove the outliers from the 'projects_completed' column based on Z-scores and display the cleaned column.

# %%
df_pro = df[(df["projects_completed"]<= upper_limit)&(df["projects_completed"]>=lower_limit)]
df_pro
# Out:
#          height        age     weight        income  hours_per_week  \
# 0    174.967142  27.923146  75.366810  37565.074836       32.027862
# 1    168.617357  32.896773  78.411768  41597.284397       37.003125
# 2    176.476885  33.286427  86.245769  61209.404077       40.026218
# 3    185.230299  30.988614  85.807031  59155.553982       40.234903
# 4    167.658466  34.193571  49.334959  49686.476091       37.749673
# ..          ...        ...        ...           ...             ...
# 96   172.961203  30.580713  83.493998  24302.982064       34.813769
# 97   172.610553  35.768626  74.609493  70308.085612       39.048307
# 98   170.051135  35.291044  82.192932  48281.902321       35.621909
# 99   167.654129  29.285149  79.444433  68567.244680       33.086001
# 101  120.000000  10.000000  30.000000  20000.000000       10.000000
#
#      years_experience  satisfaction  performance  projects_completed  \
# 0           12.778533      8.513977    69.772770            6.876568
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.distplot(df["projects_completed"])
plt.title("before removal outliers")

# after removal ourliers
plt.subplot(1,2,2)
sns.distplot(df_pro["projects_completed"])
plt.title("after removal outliers")
            
plt.show()

# %% [markdown]
# ### Calculate the Z-scores for the 'bonus' column and identify outliers.

# %%
upper_limit = df["bonus"].mean() + 3 * df["bonus"].std()
lower_limit = df["bonus"].mean()  - 3 * df["bonus"].std()
upper_limit , lower_limit
# Out:
# (11729.281190114018, -3384.7563866360197)

# %%
df[(df["bonus"]>=upper_limit)|(df["bonus"]<= lower_limit)]
# Out:
#      height   age  weight    income  hours_per_week  years_experience  \
# 100   250.0  80.0   150.0  150000.0            80.0              30.0
#
#      satisfaction  performance  projects_completed    bonus
# 100          10.0        100.0                15.0  20000.0

# %% [markdown]
# ###  Remove the outliers from the 'bonus' column based on Z-scores and display the cleaned column.

# %%
df_bonus =df[(df["bonus"]<=upper_limit)&(df["bonus"]>= lower_limit)]
df_bonus
# Out:
#          height        age     weight        income  hours_per_week  \
# 0    174.967142  27.923146  75.366810  37565.074836       32.027862
# 1    168.617357  32.896773  78.411768  41597.284397       37.003125
# 2    176.476885  33.286427  86.245769  61209.404077       40.026218
# 3    185.230299  30.988614  85.807031  59155.553982       40.234903
# 4    167.658466  34.193571  49.334959  49686.476091       37.749673
# ..          ...        ...        ...           ...             ...
# 96   172.961203  30.580713  83.493998  24302.982064       34.813769
# 97   172.610553  35.768626  74.609493  70308.085612       39.048307
# 98   170.051135  35.291044  82.192932  48281.902321       35.621909
# 99   167.654129  29.285149  79.444433  68567.244680       33.086001
# 101  120.000000  10.000000  30.000000  20000.000000       10.000000
#
#      years_experience  satisfaction  performance  projects_completed  \
# 0           12.778533      8.513977    69.772770            6.876568
# ...

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
sns.distplot(df["bonus"])
plt.title("before removal outliers")

# after removal ourliers
plt.subplot(1,2,2)
sns.distplot(df_bonus["bonus"])
plt.title("after removal outliers")
            
plt.show()
